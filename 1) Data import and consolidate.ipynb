# %%
import json
#setting up drive and importing data
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
import tweepy,json
access_token="3008102786-Y5Vik3DxtyTJ21xalN3OahEPBoZCHYrHNLbGa7Q"
access_token_secret="PuBFbDI4aL44kr9Dfps5ACQGeDM9oAZoXxW8AKbdLHXy3"
consumer_key="rsNEOPfl8GNGWkqVVyNlTLzDY"
consumer_secret="uNxMPfG6RpLut3AeDzSYchqIvarJtc3KyAquX3gROh7oerUoa7"
auth= tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
tweet_list=[]
class MyStreamListener(tweepy.StreamListener):
    def __init__(self,api=None):
        super(MyStreamListener,self).__init__()
        self.num_tweets=0
        self.file=open("/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (12).txt","w")
    def on_status(self,status):
        tweet=status._json
        self.file.write(json.dumps(tweet)+ '\n')
        tweet_list.append(status)
        self.num_tweets+=1
        if self.num_tweets<100000:
            return True
        else:
            return False
        self.file.close()

# %% [markdown]
# # New Section

# %%
#create streaming object and authenticate
l = MyStreamListener()
stream =tweepy.Stream(auth,l)
#this line filters twitter streams to capture data by keywords
stream.filter(track=['Pfizer'],languages=['en'])

# %%
import glob

read_files = glob.glob("/content/drive/Shareddrives/IDS561/twitter_data_consolidated/*.txt")

with open("twitter_data_consolidated.txt", "wb") as outfile:
    for f in read_files:
        with open(f, "rb") as infile:
            outfile.write(infile.read())

# %%
df0=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (0).txt', header=None, sep='\n')
df0= df0.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df0.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df0['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df0=pd.DataFrame(tweets_data)

# %%
#df1
df1=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (1).txt', header=None, sep='\n')
df1= df1.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df1.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df1['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df1=pd.DataFrame(tweets_data)

# %%
#df2

df2=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (2).txt', header=None, sep='\n')
df2= df2.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df2.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df2['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df2=pd.DataFrame(tweets_data)

# %%
#df3
df3=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (3).txt', header=None, sep='\n')
df3= df3.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df3.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df3['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df3=pd.DataFrame(tweets_data)

# %%
#df4
df4=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (4).txt', header=None, sep='\n')
df4= df4.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df4.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df4['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df4=pd.DataFrame(tweets_data)

# %%
#df5
df5=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (5).txt', header=None, sep='\n')
df5= df5.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df5.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df5['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df5=pd.DataFrame(tweets_data)

# %%
#df6
df6=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (6).txt', header=None, sep='\n')
df6= df6.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df6.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df6['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df6=pd.DataFrame(tweets_data)

# %%
#df7
df7=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (7).txt', header=None, sep='\n')
df7= df7.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df7.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df7['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df7=pd.DataFrame(tweets_data)

# %%
#df8
df8=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (8).txt', header=None, sep='\n')
df8= df8.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df8.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df8['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df8=pd.DataFrame(tweets_data)

# %%
#df11
df11=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (11).txt', header=None, sep='\n')
df11= df11.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df11.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df11['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df11=pd.DataFrame(tweets_data)

# %%
#df12
df12=pd.read_csv('/content/drive/Shareddrives/IDS561/twitter_data_consolidated/tweet (12).txt', header=None, sep='\n')
df12= df12.rename({0: 'text'}, axis=1) 
tweets_data=[]
a,b=df12.shape
i=0
for i in range(0,a-2):
  tweet=i
  tweet=json.loads(df12['text'][i])
  tweet
  tweets_data.append(tweet)
 

pd.set_option('display.max_columns', None)
df12=pd.DataFrame(tweets_data)

# %%
consolidated_df=[df0,df1,df2,df3,df4,df5,df6,df7,df8,df11,df12]
df_final=pd.concat(consolidated_df)
df_final.head()
df_final.to_csv('/content/drive/Shareddrives/IDS561/Output_Oct-12_v2.csv')
print(df_final.shape)
# Out:
# (109288, 37)
